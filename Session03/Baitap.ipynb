# %%
#Bài 1
a = int(input("Nhập số a: "))
b = int(input("Nhập số b: "))

def sub(a, b):
    return a - b

def mul(a, b):
    return a * b

print("Hiệu của a và b là:", sub(a, b))
print("Tích của a và b là:", mul(a, b))
# Out:
# Hiệu của a và b là: 9
# Tích của a và b là: 10

# %%
#Bài 2
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

num = int(input("Nhập một số nguyên: "))

if is_prime(num):
    print(f"{num} là số nguyên tố.")
else:
    print(f"{num} không phải là số nguyên tố.")
# Out:
# 5 là số nguyên tố.

# %%
# Bài 3
def factorial(n):   
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)

number = int(input("Nhập một số nguyên không âm: "))
if number < 0:
    print("Vui lòng nhập số không âm.")
else:
    print(f"Giai thừa của {number} là: {factorial(number)}")
# Out:
# Giai thừa của 5 là: 120

# %%
# Bài 4
import math
def circle_area(radius):
    return math.pi * radius * radius

interval_radius = float(input("Nhập bán kính hình tròn: "))
print(f"Diện tích hình tròn có bán kính {interval_radius} là:", circle_area(interval_radius))
# Out:
# Diện tích hình tròn có bán kính 56.0 là: 9852.03456165759

# %%
# Bài 5
def is_leap_year(year):
    if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
        return True
    return False

year = int(input("Nhập một năm: "))
if is_leap_year(year):
    print(f"{year} là năm nhuận.") 
else:
    print(f"{year} không phải là năm nhuận.")
# Out:
# 200 không phải là năm nhuận.

# %%
# Bài 6
def sum_of_digits(n):
    total = 0
    while n > 0:
        total += n % 10
        n //= 10
    return total  
number = int(input("Nhập một số nguyên dương: "))
if number < 0:
    print("Vui lòng nhập số nguyên dương.") 
else:
    print(f"Tổng các chữ số trong {number} là:", sum_of_digits(number))
# Out:
# Tổng các chữ số trong 123 là: 6

# %%
# Bài 7
def reverse_number(n):
    reversed_num = 0
    while n > 0:
        digit = n % 10
        reversed_num = reversed_num * 10 + digit
        n //= 10
    return reversed_num

number = int(input("Nhập một số nguyên dương: "))
if number < 0:
    print("Vui lòng nhập số nguyên dương.")
else:
    print(f"Số đảo ngược của {number} là:", reverse_number(number))
# Out:
# Số đảo ngược của 123 là: 321

# %%
#Bài 8
def is_perfect_number(n):
    if n < 2:
        return False
    divisors_sum = sum(i for i in range(1, n) if n % i == 0)
    return divisors_sum == n

number = int(input("Nhập một số nguyên dương: "))
if is_perfect_number(number):
    print(f"{number} là số hoàn hảo.")
else:
    print(f"{number} không phải là số hoàn hảo.")
# Out:
# 6 là số hoàn hảo.
